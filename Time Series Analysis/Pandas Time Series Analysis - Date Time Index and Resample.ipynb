# %%
import pandas as pd
df = pd.read_csv("aapl.csv", parse_dates = ["Date"], index_col = "Date")
df.head(5)
# Out:
# C:\Users\Archita Shrivastava\AppData\Local\Temp\ipykernel_18032\1240927472.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("aapl.csv", parse_dates = ["Date"], index_col = "Date")
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
df = df.sort_index()
df["2017-01-07":"2017-01-01"]     # this still won’t work because it's reverse
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %%
df.Close.resample('M').mean().plot()
# Out:
# C:\Users\Archita Shrivastava\AppData\Local\Temp\ipykernel_18032\4123725665.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('M').mean()
# Out:
# C:\Users\Archita Shrivastava\AppData\Local\Temp\ipykernel_18032\3510564528.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean()
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: ME, Name: Close, dtype: float64

# %%
# %matplotlib inline
df.Close.resample('Q').mean().plot()
# Out:
# C:\Users\Archita Shrivastava\AppData\Local\Temp\ipykernel_18032\942972382.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.Close.resample('Q').mean().plot()
# Out:
# C:\Users\Archita Shrivastava\AppData\Local\Temp\ipykernel_18032\3189526837.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot()
# <Axes: xlabel='Date'>
